# %%
job_title = 'Data Analyst'
job_location = 'United States'
job_salary = 90000

# %%
class JobPost:
    def __init__(self, title, location, salary):
        self.title = title
        self.location = location
        self.salary = salary

# %%
job_1 = JobPost(job_title, job_location, job_salary)

# %%
job_1.title
# Out:
# 'Data Analyst'

# %%
job_requirement = 'SQL'
application_skill = 'Excel'
experience = 7

if application_skill == job_requirement:
    print('Skilled')
elif application_skill == 'python':
    print ('skilled')
elif experience > 10:
    print ('Experienced','and', 'Skilled')
else:
    print('No Experience', 'and ', 'No Skill')
# Out:
# No Experience and  No Skill

# %%
job_list = [
    "Software Engineer", "Data Analyst I", "Marketing Manager", "Product Manager", "Graphic Designer",
    "Sales Executive", "HR Coordinator", "IT Support", "Business Analyst", "Data Scientist",
    "Operations Manager", "Financial Analyst", "UX Designer", "Data Engineer", "Systems Analyst",
    "Data Analyst II", "Web Developer", "Digital Marketing Specialist", "Recruitment Officer", "Logistics Manager",
    "Customer Service Representative", "Database Administrator", "Mobile App Developer", "Cloud Architect", "Network Engineer",
    "Security Analyst", "Frontend Developer", "Backend Developer", "Machine Learning Engineer", "Statistician",
    "Quality Assurance Tester", "Risk Manager", "Research Assistant", "Legal Advisor", "Data Entry Clerk",
    "Scrum Master", "Business Intelligence Analyst", "IT Auditor", "CRM Specialist", "DevOps Engineer",
    "Technical Writer", "Content Strategist", "Public Relations Officer", "Digital Strategist", "Full Stack Developer",
    "Accountant", "Chief Technology Officer", "Innovation Consultant", "Procurement Officer", "Junior Data Analyst"
]

# %%
analyze = []

# %%
for job in job_list:
    if 'Data Analyst' in job:
        analyze.append(job)

# %%
analyze
# Out:
# ['Data Analyst I', 'Data Analyst II', 'Junior Data Analyst']

# %%
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]

# %%
my_skills = ['Python', 'SQL', 'Excel']

# %%
analyze_2 = []

# %%
for job in job_roles:
    qualified = True
    
    for skills in my_skills:
        if skills not in job['skills']:
            qualified = False
            break
            
    if qualified:
        analyze_2.append(job['role'])

# %%
analyze_2
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %%
salary_list = [100000, 200000, 150000, 120000, 80000, 750000]

# %%
salary_101 = [(lambda x:x*1.1)(salary) for salary in salary_list]

# %%
salary_101
# Out:
# [110000.00000000001,
#  220000.00000000003,
#  165000.0,
#  132000.0,
#  88000.0,
#  825000.0000000001]

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
list(filter(lambda job: job['remote'],jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True},
#  {'job_title': 'Software Developer',
#   'job_skills': ['Java', 'C++'],
#   'remote': True}]

# %%
list(filter(lambda job: job['remote'] and 'Python' in job['job_skills'], jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True}]

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 7, 28, 18, 33, 2, 190662)

# %%
data_science_jobs[0]['job_date']
# Out:
# '2023-05-12'

# %%
test_date = data_science_jobs[0]['job_date']

# %%
type(test_date)
# Out:
# str

# %%
date_100 = datetime.strptime(test_date, '%Y-%m-%d')

# %%
type(date_100)
# Out:
# datetime.datetime

# %%
for time in data_science_jobs:
    time['job_date'] = datetime.strptime(time['job_date'], '%Y-%m-%d')

# %%
type(data_science_jobs[0]['job_date'])
# Out:
# datetime.datetime

# %%
import pandas as pd

# %%
import numpy as np

# %%
from datetime import datetime

# %%
# !pip install
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\FMVA Plus Extras\Financial Modeling, Software, Maths\Python\Data Analysis 2\data_jobs.csv')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_title_short'].head()
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# Name: job_title_short, dtype: object

# %%
df[['job_title_short','job_location']].head(10)
# Out:
#         job_title_short                  job_location
# 0  Senior Data Engineer                 Watertown, CT
# 1          Data Analyst  Guadalajara, Jalisco, Mexico
# 2         Data Engineer               Berlin, Germany
# 3         Data Engineer               San Antonio, TX
# 4         Data Engineer                Washington, DC
# 5         Data Engineer                      Anywhere
# 6  Senior Data Engineer                  Dearborn, MI
# 7         Data Engineer                      Anywhere
# 8      Business Analyst           Copenhagen, Denmark
# 9        Data Scientist                      Anywhere

# %%
df.iloc[90:100, 0:3]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location
# 90                   Australia
# 91               Temuco, Chile
# 92                    Anywhere
# ...

# %%
df.shape
# Out:
# (785741, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[df.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df[['job_title_short','salary_year_avg']][(df.job_title_short == 'Data Analyst') & (df.salary_year_avg >100000)]
# Out:
#        job_title_short  salary_year_avg
# 410       Data Analyst         133285.0
# 1555      Data Analyst         111175.0
# 1681      Data Analyst         111175.0
# 1684      Data Analyst         120000.0
# 1867      Data Analyst         101500.0
# ...                ...              ...
# 783588    Data Analyst         125000.0
# 783866    Data Analyst         115000.0
# 784033    Data Analyst         111175.0
# 785187    Data Analyst         111175.0
# 785515    Data Analyst         105000.0
#
# [1976 rows x 2 columns]

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
type(df['job_posted_date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values(by='job_posted_date', inplace= True)

# %%
df.head(4)
# Out:
#        job_title_short     job_title    job_location            job_via  \
# 108804    Data Analyst  Data Analyst    New York, NY  via CareerBuilder
# 96906     Data Analyst  Data Analyst  Bloomfield, CT  via CareerBuilder
# 98438     Data Analyst  Data Analyst  Washington, DC  via CareerBuilder
# 110290    Data Analyst  Data Analyst     Fairfax, VA  via CareerBuilder
#
#        job_schedule_type  job_work_from_home          search_location  \
# 108804         Full-time               False  New York, United States
# 96906          Full-time               False  New York, United States
# 98438          Full-time               False  New York, United States
# 110290         Full-time               False  New York, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 108804 2023-01-01 00:00:04                  False                 False
# 96906  2023-01-01 00:00:07                   True                 False
# ...

# %%
df.drop('salary_hour_avg', axis=1, inplace = True)

# %%
df.head(4)
# Out:
#        job_title_short     job_title    job_location            job_via  \
# 108804    Data Analyst  Data Analyst    New York, NY  via CareerBuilder
# 96906     Data Analyst  Data Analyst  Bloomfield, CT  via CareerBuilder
# 98438     Data Analyst  Data Analyst  Washington, DC  via CareerBuilder
# 110290    Data Analyst  Data Analyst     Fairfax, VA  via CareerBuilder
#
#        job_schedule_type  job_work_from_home          search_location  \
# 108804         Full-time               False  New York, United States
# 96906          Full-time               False  New York, United States
# 98438          Full-time               False  New York, United States
# 110290         Full-time               False  New York, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 108804 2023-01-01 00:00:04                  False                 False
# 96906  2023-01-01 00:00:07                   True                 False
# ...

# %%
df.dropna(subset='salary_year_avg',inplace=True)

# %%
df.head(4)
# Out:
#          job_title_short                       job_title   job_location  \
# 108883    Data Scientist                  Data Scientist  Calabasas, CA
# 334082     Data Engineer                   Data Engineer      Argentina
# 365786  Business Analyst  Hospitality Operations Analyst       Anywhere
# 366073      Data Analyst     Data Analytics Professional    Atlanta, GA
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 334082                        via EchoJobs         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
# 366073                   via CareerBuilder         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# 334082               False                  Argentina 2023-01-01 00:06:13
# ...

# %%
df.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['max','min'])
# Out:
#                                 max      min
# job_title_short
# Business Analyst           387460.0  16500.0
# Cloud Engineer             280000.0  42000.0
# Data Analyst               650000.0  25000.0
# Data Engineer              525000.0  15000.0
# Data Scientist             960000.0  27000.0
# Machine Learning Engineer  325000.0  30000.0
# Senior Data Analyst        425000.0  30000.0
# Senior Data Engineer       425000.0  35000.0
# Senior Data Scientist      890000.0  45000.0
# Software Engineer          375000.0  28000.0

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg'].mean()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                71100.000000
#                    Australia                87666.666667
#                    Bangladesh               16500.000000
#                    Belgium                  82620.000000
#                    Bulgaria                 73987.500000
#                                                ...
# Software Engineer  Ukraine                  54000.000000
#                    United Arab Emirates     79200.000000
#                    United Kingdom          103280.000000
#                    United States           137964.929588
#                    Vietnam                  53600.000000
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
df['job_country'].value_counts().head(10)
# Out:
# job_country
# United States     15766
# Sudan              1623
# India               582
# Canada              463
# United Kingdom      287
# Germany             257
# France              237
# Poland              200
# Spain               144
# Portugal            131
# Name: count, dtype: int64

# %%
us_job = df[df.job_country == 'United States']

# %%
us_job
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
us_job = us_job.dropna(subset = 'salary_year_avg')

# %%
us_job
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
us_job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15766 entries, 108883 to 313161
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        15766 non-null  object
#  1   job_title              15766 non-null  object
#  2   job_location           15544 non-null  object
#  3   job_via                15766 non-null  object
#  4   job_schedule_type      15752 non-null  object
#  5   job_work_from_home     15766 non-null  bool
#  6   search_location        15766 non-null  object
#  7   job_posted_date        15766 non-null  datetime64[ns]
#  8   job_no_degree_mention  15766 non-null  bool
#  9   job_health_insurance   15766 non-null  bool
#  10  job_country            15766 non-null  object
#  11  salary_rate            15766 non-null  object
#  12  salary_year_avg        15766 non-null  float64
#  13  company_name           15766 non-null  object
# ...

# %%
us_job.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              96175.447397
# Cloud Engineer               120090.900000
# Data Analyst                  94553.964924
# Data Engineer                134226.676753
# Data Scientist               139946.707204
# Machine Learning Engineer    154240.382812
# Senior Data Analyst          115729.129954
# Senior Data Engineer         151448.023186
# Senior Data Scientist        159330.432029
# Software Engineer            137964.929588
# Name: salary_year_avg, dtype: float64

# %%
us_job.groupby('job_title_short')['salary_year_avg'].mean().sort_values(ascending = False).round(1)
# Out:
# job_title_short
# Senior Data Scientist        159330.4
# Machine Learning Engineer    154240.4
# Senior Data Engineer         151448.0
# Data Scientist               139946.7
# Software Engineer            137964.9
# Data Engineer                134226.7
# Cloud Engineer               120090.9
# Senior Data Analyst          115729.1
# Business Analyst              96175.4
# Data Analyst                  94554.0
# Name: salary_year_avg, dtype: float64

# %%
us_job.groupby('job_title_short')['job_title_short'].value_counts()
# Out:
# job_title_short
# Business Analyst              431
# Cloud Engineer                 20
# Data Analyst                 4350
# Data Engineer                2915
# Data Scientist               4553
# Machine Learning Engineer     128
# Senior Data Analyst           913
# Senior Data Engineer         1058
# Senior Data Scientist        1241
# Software Engineer             157
# Name: count, dtype: int64

# %%
us_job.groupby('job_title_short')['salary_year_avg'].agg(['median','min','max','count']).sort_values(by= 'median' , ascending= False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0   1241
# Machine Learning Engineer  150000.0  44408.5  315000.0    128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058
# Data Scientist             130000.0  30000.0  960000.0   4553
# Software Engineer          130000.0  48982.0  375000.0    157
# Data Engineer              125000.0  23496.0  525000.0   2915
# Cloud Engineer             116100.0  42000.0  221844.0     20
# Senior Data Analyst        110000.0  35360.0  425000.0    913
# Business Analyst            90000.0  35000.0  387460.0    431
# Data Analyst                90000.0  25000.0  375000.0   4350

# %%
us_job.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values(by='median', ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0   1241
# Machine Learning Engineer  150000.0  44408.5  315000.0    128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058
# Data Scientist             130000.0  30000.0  960000.0   4553
# Software Engineer          130000.0  48982.0  375000.0    157
# Data Engineer              125000.0  23496.0  525000.0   2915
# Cloud Engineer             116100.0  42000.0  221844.0     20
# Senior Data Analyst        110000.0  35360.0  425000.0    913
# Business Analyst            90000.0  35000.0  387460.0    431
# Data Analyst                90000.0  25000.0  375000.0   4350

# %%
df['job_posted_month1'] = df.job_posted_date.dt.month

# %%
df.drop('job_posted_month1', axis=1, inplace=True)

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
monthly_counts = df['job_posted_month'].value_counts()

# %%
monthly_counts
# Out:
# job_posted_month
# 6     2331
# 1     2296
# 7     2219
# 3     2204
# 8     2095
# 2     2010
# 5     1911
# 4     1876
# 12    1381
# 10    1310
# 9     1246
# 11    1124
# Name: count, dtype: int64

# %%
monthly_counts.sort_index(inplace=True)

# %%
monthly_counts
# Out:
# job_posted_month
# 1     2296
# 2     2010
# 3     2204
# 4     1876
# 5     1911
# 6     2331
# 7     2219
# 8     2095
# 9     1246
# 10    1310
# 11    1124
# 12    1381
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index,monthly_counts)
plt.xlabel('Months')
plt.ylabel('Number of Months')
plt.show()

# %%
job_counts = df['job_title_short'].value_counts().sort_values(ascending=True)

# %%
job_counts
# Out:
# job_title_short
# Cloud Engineer                 65
# Software Engineer             467
# Machine Learning Engineer     576
# Business Analyst              610
# Senior Data Analyst          1131
# Senior Data Engineer         1591
# Senior Data Scientist        1690
# Data Engineer                4500
# Data Analyst                 5451
# Data Scientist               5922
# Name: count, dtype: int64

# %%
plt.barh(job_counts.index, job_counts)
plt.xlabel('xx')
plt.ylabel('yy')
plt.show()

# %%
plt.bar(job_counts.index, job_counts)
plt.xlabel('xx')
plt.ylabel('yy')
plt.xticks(rotation=45 ,ha='right')
plt.show()

# %%
df.head(3)
# Out:
#          job_title_short                       job_title   job_location  \
# 108883    Data Scientist                  Data Scientist  Calabasas, CA
# 334082     Data Engineer                   Data Engineer      Argentina
# 365786  Business Analyst  Hospitality Operations Analyst       Anywhere
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 334082                        via EchoJobs         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# 334082               False                  Argentina 2023-01-01 00:06:13
# 365786                True                    Georgia 2023-01-01 00:17:55
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# ...

# %%
type(df['job_posted_date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
job_salary = df.groupby('job_title_short')['salary_year_avg'].mean().sort_values()

# %%
job_salary
# Out:
# job_title_short
# Business Analyst              91082.612833
# Data Analyst                  93841.907854
# Cloud Engineer               111268.453846
# Software Engineer            113393.760054
# Senior Data Analyst          113911.363665
# Machine Learning Engineer    126774.315972
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Name: salary_year_avg, dtype: float64

# %%
plt.barh(job_salary.index,job_salary)
plt.title('xxxx')
plt.xlabel('xx')
plt.ylabel('yy')
plt.show()
